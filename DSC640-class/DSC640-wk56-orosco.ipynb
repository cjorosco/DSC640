# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import squarify
import os
os.getcwd()
# Out:
# '/Users/corosco/DSC640/DSC640-class/week-5-6/data'

# %%
#read file
df = pd.read_csv(r"unemployement-rate-1948-2010.csv")
df.drop(['Series id'], axis=1, inplace=True)

# %%
# group by year
df_group = df.groupby("Year")[["Value"]].mean()
df_group.columns
# Out:
# Index(['Value'], dtype='object')

# %%
# Display the Treemap

squarify.plot(sizes=df_group.values, color=["skyblue", "lightgreen", "yellow"], label=df_group.index, alpha=0.7)

# Removing the axis values
plt.axis('off')

# Displaying the plot
plt.show()

# %%
df_group.Value
# Out:
# Year
# 1948    3.750000
# 1949    6.050000
# 1950    5.208333
# 1951    3.283333
# 1952    3.025000
#           ...
# 2006    4.608333
# 2007    4.608333
# 2008    5.816667
# 2009    9.275000
# 2010    9.700000
# Name: Value, Length: 63, dtype: float64

# %%
# Display Area Chart

plt.fill_between(df_group.index, df_group.Value)
plt.title("Mean Unemployment Rate Per Year from 1948 - 2010")
plt.xlabel("Year")
plt.ylabel("Unemployment Rate")
plt.show()

# %%
# Reshape DF because Pandas plot requires data be in rows and unique columns for layers
pivot_df = df.pivot(index=['Year'], columns=['Period'], )

# %%
# Display Stacked Area Chart
pivot_df.plot.area()
plt.title("Unemployment Rate Per Period from 1948 -2010")
plt.xlabel("Year")
plt.ylabel("Unemployment Rate")
plt.legend(bbox_to_anchor = (1,1))
plt.show()
